# %%
def booking():
    start_point=int(input("Enter the start point: "))
    end_point=int(input("Enter the end point: "))
    total_distance=end_point-start_point
    print(total_distance)
    category=("Micro","Mini","SUV","Luxury")
    cat_micro=("Hyundai Eon","Datsun Go")
    cat_mini=("Skoda Rapid","Honda Civic")
    cat_suv=("Toyota Innova","Nissan Evalia ")
    cat_luxury=("Toyota Camry","Toyota Fortuner")
    print("The category of cars available are:{}".format(category))
    seclected_category=input("The category of cars you chose is:")
    if seclected_category=="Micro":
        print("The cars available are:{}".format(cat_micro))
        seclected_car=str(input("The car you chose is:"))
        print("The tariff plan:\n Base tariff is 55 for the first 5 kms\n 15₹ for the consequetive distance")
        print("You could 'Accept' or 'Deny'")
        ride=str(input("Do you like to proceed: "))
        if ride=="Accept":
            if total_distance<=5:
                amount_payable=55
                print("The total fare is :{}".format(amount_payable))
                print("____________________________________________________________________________")
                print("_________________________________BILL_______________________________________")
                print("____________________________________________________________________________")
                print("Total amount distance taravelled is {}".format(total_distance))
                print("The car you took the ride is {}".format(seclected_car))
                print("The total fare paid:{}".format(amount_payable))
            elif total_distance>5:
                next_distance=total_distance-5
                amount_payable=55+next_distance*15
                print("The total fare is :{}".format(amount_payable))
                print("____________________________________________________________________________")
                print("_________________________________BILL_______________________________________")
                print("____________________________________________________________________________")
                print("Total amount distance taravelled is {}".format(total_distance))
                print("The car you took the ride is {}".format(seclected_car))
                print("The total fare paid:{}".format(amount_payable))
            else:
                pass
        else:
            pass
    elif seclected_category=="Mini":
        print("The cars available are:{}".format(cat_mini))
        seclected_car=str(input("The car you chose is:"))
        print("The tariff plan:\n Base tariff is 75 for the first 5 kms\n 20₹ for the consequetive distance")
        print("You could 'Accept' or 'Deny'")
        ride=str(input("Do you like to proceed: "))
        if ride=="Accept":
            if total_distance<=5:
                amount_payable=75
                print("The total fare is :{}".format(amount_payable))
                print("____________________________________________________________________________")
                print("_________________________________BILL_______________________________________")
                print("____________________________________________________________________________")
                print("Total amount distance taravelled is {}".format(total_distance))
                print("The car you took the ride is {}".format(seclected_car))
                print("The total fare paid:{}".format(amount_payable))
            elif total_distance>5:
                next_distance=total_distance-5
                amount_payable=75+next_distance*20
                print("The total fare is :{}".format(amount_payable))
                print("____________________________________________________________________________")
                print("_________________________________BILL_______________________________________")
                print("____________________________________________________________________________")
                print("Total amount distance taravelled is {}".format(total_distance))
                print("The car you took the ride is {}".format(seclected_car))
                print("The total fare paid:{}".format(amount_payable))
            else:
                pass
        else:
            pass
    elif seclected_category=="SUV":
        print("The cars available are:{}".format(cat_suv))
        seclected_car=str(input("The car you chose is:"))
        print("The tariff plan:\n Base tariff is 100 for the first 5 kms\n 25₹ for the consequetive distance")
        print("You could 'Accept' or 'Deny'")
        ride=str(input("Do you like to proceed: "))
        if ride=="Accept":
            if total_distance<=5:
                amount_payable=100
                print("The total fare is :{}".format(amount_payable))
                print("____________________________________________________________________________")
                print("_________________________________BILL_______________________________________")
                print("____________________________________________________________________________")
                print("Total amount distance taravelled is {}".format(total_distance))
                print("The car you took the ride is {}".format(seclected_car))
                print("The total fare paid:{}".format(amount_payable))
            elif total_distance>5:
                next_distance=total_distance-5
                amount_payable=100+next_distance*25
                print("The total fare is :{}".format(amount_payable))
                print("____________________________________________________________________________")
                print("_________________________________BILL_______________________________________")
                print("____________________________________________________________________________")
                print("Total amount distance taravelled is {}".format(total_distance))
                print("The car you took the ride is {}".format(seclected_car))
                print("The total fare paid:{}".format(amount_payable))
            else:
                pass
        else:
            pass
    elif seclected_category=="Luxury":
        print("The cars available are:{}".format(cat_luxury))
        seclected_car=str(input("The car you chose is:"))
        print("The tariff plan:\n Base tariff is 150 for the first 5 kms\n 30₹ for the consequetive distance")
        print("You could 'Accept' or 'Deny'")
        ride=str(input("Do you like to proceed: "))
        if ride=="Accept":
            if total_distance<=5:
                amount_payable=150
                print("The total fare is :{}".format(amount_payable))
                print("____________________________________________________________________________")
                print("_________________________________BILL______________________________________")
                print("____________________________________________________________________________")
                print("Total amount distance taravelled is {}".format(total_distance))
                print("The car you took the ride is {}".format(seclected_car))
                print("The total fare paid:{}".format(amount_payable))
            elif total_distance>5:
                next_distance=total_distance-5
                amount_payable=150+next_distance*30
                print("The total fare is :{}".format(amount_payable))
                print("____________________________________________________________________________")
                print("_________________________________BILL_______________________________________")
                print("____________________________________________________________________________")
                print("Total amount distance taravelled is {}".format(total_distance))
                print("The car you took the ride is {}".format(seclected_car))
                print("The total fare paid:{}".format(amount_payable))
            else:
                pass
        else:
            pass
    else:
        pass

# %%
import re
print("The username should be of the following:\n6 to 8 character\nAtleast one number,uppercase & lowercase letter")
u=str(input('Create an username: '))
x = True
while x:  
    if (len(u)<6 or len(u)>12):
        break
    elif not re.search("[a-z]",u):
        break
    elif not re.search("[0-9]",u):
        break
    elif not re.search("[A-Z]",u):
        break
    elif not re.search("[$#@]",u):
        break
    else:
        print("Valid Password")
        x=False
        break
print("The username should be of the following:\n6 to 8 character\nAtleast one number,uppercase & lowercase letter")
p= input("Input your password : ")
y = True
while y:  
    if (len(p)<6 or len(p)>12):
        break
    elif not re.search("[a-z]",p):
        break
    elif not re.search("[0-9]",p):
        break
    elif not re.search("[A-Z]",p):
        break
    elif not re.search("[$#@]",p):
        break
    else:
        print("Valid Password")
        x=False
        break

if x:
    print("Not a Valid Password")
count=0
while count < 3:
    username = input('Enter username: ')
    password = input('Enter password: ')
    if password==p and username==u:
        print('Access granted')
        booking()
        break
    else:
        print('Access denied. Try again.')
        count += 1
    while count==3:
        if password!='password' and username!='username':
            print('Terminated')
        break
# Out:
# The username should be of the following:
# 6 to 8 character
# Atleast one number,uppercase & lowercase letter
# Create an username: Abc@123
# Valid Password
# The username should be of the following:
# 6 to 8 character
# Atleast one number,uppercase & lowercase letter
# Input your password : Zyx#987
# Valid Password
# Enter username: Abc@123
# Enter password: Zyx#987
# Access granted
# Enter the start point: 8
# Enter the end point: 25
# 17
# The category of cars available are:('Micro', 'Mini', 'SUV', 'Luxury')
# The category of cars you chose is:Micro
# The cars available are:('Hyundai Eon', 'Datsun Go')
# The car you chose is:Hyundai Eon
# The tariff plan:
#  Base tariff is 55 for the first 5 kms
#  15₹ for the consequetive distance
# You could 'Accept' or 'Deny'
# Do you like to proceed: Accept
# The total fare is :235
# ____________________________________________________________________________
# _________________________________BILL_______________________________________
# ...

# %%
import re
print("The username should be of the following:\n6 to 8 character\nAtleast one number,uppercase & lowercase letter")
u=str(input('Create an username: '))
x = True
while x:  
    if (len(u)<6 or len(u)>12):
        break
    elif not re.search("[a-z]",u):
        break
    elif not re.search("[0-9]",u):
        break
    elif not re.search("[A-Z]",u):
        break
    elif not re.search("[$#@]",u):
        break
    elif re.search("\s",u):
        break
    else:
        print("Valid Password")
        x=False
        break
print("The username should be of the following:\n6 to 8 character\nAtleast one number,uppercase & lowercase letter")
p= input("Input your password : ")
y = True
while y:  
    if (len(p)<6 or len(p)>12):
        break
    elif not re.search("[a-z]",p):
        break
    elif not re.search("[0-9]",p):
        break
    elif not re.search("[A-Z]",p):
        break
    elif not re.search("[$#@]",p):
        break
    elif re.search("\s",p):
        break
    else:
        print("Valid Password")
        x=False
        break

if x:
    print("Not a Valid Password")
count=0
while count < 3:
    username = input('Enter username: ')
    password = input('Enter password: ')
    if password==p and username==u:
        print('Access granted')
        booking()
        break
    else:
        print('Access denied. Try again.')
        count += 1
    while count==3:
        if password!='password' and username!='username':
            print('Terminated')
        break
# Out:
# The username should be of the following:
# 6 to 8 character
# Atleast one number,uppercase & lowercase letter
# Create an username: Abc@123
# Valid Password
# The username should be of the following:
# 6 to 8 character
# Atleast one number,uppercase & lowercase letter
# Input your password : Zyx$987
# Valid Password
# Enter username: Abc@123
# Enter password: Zyx$987
# Access granted
# Enter the start point: 8
# Enter the end point: 78
# 70
# The category of cars available are:('Micro', 'Mini', 'SUV', 'Luxury')
# The category of cars you chose is:Luxury
# The cars available are:('Toyota Camry', 'Toyota Fortuner')
# The car you chose is:Toyota Fortuner
# The tariff plan:
#  Base tariff is 150 for the first 5 kms
#  30₹ for the consequetive distance
# You could 'Accept' or 'Deny'
# Do you like to proceed: Accept
# The total fare is :2100
# ____________________________________________________________________________
# ...
