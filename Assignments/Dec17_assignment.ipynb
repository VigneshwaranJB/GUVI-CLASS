# %%
#Get the value of the total amount
n = int(input("Enter the total amount : "))
#list of types 
notes_available=[2000,500,200,100,50,20,10,5,2,1]
#run through the amount in every denomination staring from the highest denomination
nott=n//2000
remtt=n%2000
#run through 500s
nofh=remtt//500
remfh=remtt%500
#run through 200s
noth=remfh//200
remth=remfh%200
#run through 100s
nooh=remfh//100
remoh=remfh%100
#run through 50s
nofy=remoh//50
remfy=remoh%50
#run through 20s
noty=remfy//20
remty=remoh%20
#run through 10s
noten=remty//10
remten=remty%10
#run through 5s
nofi=remten//5
remfi=remten%5
#run through 2s
notwo=remfi//2
remtwo=remfi%2
#run through 1s
noone=remtwo//1
print("The # of 2000s is {}".format(nott))
print("The # of 500s is {}".format(nofh))
print("The # of 200s is {}".format(noth))
print("The # of 100s is {}".format(nooh))
print("The # of 50s is {}".format(nofy))
print("The # of 20s is {}".format(noty))
print("The # of 10s is {}".format(noten))
print("The # of 5s is {}".format(nofi))
print("The # of 2s is {}".format(notwo))
print("The # of 1s is {}".format(noone))
# Out:
# Enter the total amount : 2749573
# The # of 2000s is 1374
# The # of 500s is 3
# The # of 200s is 0
# The # of 100s is 0
# The # of 50s is 1
# The # of 20s is 1
# The # of 10s is 1
# The # of 5s is 0
# The # of 2s is 1
# The # of 1s is 1

# %%
#I could feel that I'm really close to what I'm expecting but i couldn't get it right
#couldn't fix the error
#get the value for marks
a = int(input("Mark scored by student in maths : "))
b = int(input("Mark scored by student in science : "))
c = int(input("Mark scored by student in social : "))
d = int(input("Mark scored by student in tamil : "))
e = int(input("Mark scored by student in english : "))
#creating a directory for marklist
scorecard={"Maths":a,"Science":b,"Social":c,"Tamil":d,"English":e}
#print(scorecard)
marklist=(a,b,c,d,e)
#print(marklist)
key=scorecard.keys()
print(key)
#segregate the mark to the respective grades
for num in scorecard.values():
    if num>=90:
        print("The grade score of the student in {} is A".format(key))
    elif num>=80:
        print("The grade score of the student in {} is B".format(key))
    elif num>=70:
        print("The grade score of the student in {} is C".format(key))
    elif num>=60:
        print("The grade score of the student in {} is D".format(key))
    else:
        print("The grade score of the student in {} is E".format(key))
# Out:
# Mark scored by student in maths : 87
# Mark scored by student in science : 98
# Mark scored by student in social : 55
# Mark scored by student in tamil : 66
# Mark scored by student in english : 33
# dict_keys(['Maths', 'Science', 'Social', 'Tamil', 'English'])
# The grade score of the student in dict_keys(['Maths', 'Science', 'Social', 'Tamil', 'English']) is B
# The grade score of the student in dict_keys(['Maths', 'Science', 'Social', 'Tamil', 'English']) is A
# The grade score of the student in dict_keys(['Maths', 'Science', 'Social', 'Tamil', 'English']) is E
# The grade score of the student in dict_keys(['Maths', 'Science', 'Social', 'Tamil', 'English']) is D
# The grade score of the student in dict_keys(['Maths', 'Science', 'Social', 'Tamil', 'English']) is E

# %%
a = int(input("Mark scored by student in maths : "))
b = int(input("Mark scored by student in science : "))
c = int(input("Mark scored by student in social : "))
d = int(input("Mark scored by student in tamil : "))
e = int(input("Mark scored by student in english : "))
scorecard={"Maths":a,"Science":b,"Social":c,"Tamil":d,"English":e}
print(scorecard)
marklist=(a,b,c,d,e)
print(marklist)
if a>=90:
    print("The grade score of the student in Maths is A")
elif a>=80:
    print("The grade score of the student in Maths is B")
elif a>=70:
    print("The grade score of the student in Maths is C")
elif a>=60:
    print("The grade score of the student in Maths is D")
else:
    print("The grade score of the student in Maths is E")
if b>=90:
    print("The grade score of the student in Science is A")
elif b>=80:
    print("The grade score of the student in Science is B")
elif b>=70:
    print("The grade score of the student in Science is C")
elif b>=60:
    print("The grade score of the student in Science is D")
else:
    print("The grade score of the student in Science is E")
if c>=90:
    print("The grade score of the student in Social is A")
elif c>=80:
    print("The grade score of the student in Social is B")
elif c>=70:
    print("The grade score of the student in Social is C")
elif c>=60:
    print("The grade score of the student in Social is D")
else:
    print("The grade score of the student in Social is E")
if d>=90:
    print("The grade score of the student in Tamil is A")
elif d>=80:
    print("The grade score of the student in Tamil is B")
elif d>=70:
    print("The grade score of the student in Tamil is C")
elif d>=60:
    print("The grade score of the student in Tamil is D")
else:
    print("The grade score of the student in Tamil is E")
if e>=90:
    print("The grade score of the student in English is A")
elif e>=80:
    print("The grade score of the student in English is B")
elif e>=70:
    print("The grade score of the student in English is C")
elif e>=60:
    print("The grade score of the student in English is D")
else:
    print("The grade score of the student in English is E")
# Out:
# Mark scored by student in maths : 67
# Mark scored by student in science : 96
# Mark scored by student in social : 45
# Mark scored by student in tamil : 88
# Mark scored by student in english : 70
# {'Maths': 67, 'Science': 96, 'Social': 45, 'Tamil': 88, 'English': 70}
# (67, 96, 45, 88, 70)
# The grade score of the student in Maths is D
# The grade score of the student in Science is A
# The grade score of the student in Social is E
# The grade score of the student in Tamil is B
# The grade score of the student in English is C

# %%
a = int(input("Total amount of consumed electricity : "))
if a<=100:
    print("You don't have to pay anything")
elif 100<a<200:
    chargable_units=a-100
    amount=chargable_units*1.5+20
    print("The total charge payable {}".format(amount))
elif 200<a<500:
    chargable_units=a-100
    if chargable_units>100:
        firsthun=100
        nexunit=chargable_units-100
        amount=firsthun*2+(chargable_units-100)*3+30
    else:
        amount=chargable_units*2+30   
    print("The total charge payable {}".format(amount))
else:
    chargable_units=a-100
    if chargable_units>500:
        firstset=100
        secset=100
        thirdset=300
        nexunit=chargable_units-500
        amount=secset*3.5+thirdset*4.6+nexunit*6.6+50
        print("The total charge payable {}".format(amount))
    elif 200<chargable_units<500:
        firstset=100
        secset=100
        nexunit=chargable_units-200
        amount=secset*3.5+nexunit*4.6+50
        print("The total charge payable {}".format(amount))
    else:
        firstset=100
        nexunit=chargable_units-100
        amount=nexunit*3.5+50
        print("The total charge payable {}".format(amount))
# Out:
# Total amount of consumed electricity : 590
# The total charge payable 1734.0

# %%
lst = [] 
n = int(input("Enter number of elements : ")) 
for i in range(0, n): 
    element = int(input())   
    lst.append(element)
      
print(lst) 
for num in lst:
    if num > 1:
        for i in range(2, num):
            if (num % i) == 0:
                break
        else:
            print("The number {} is a prime number".format(num))
# Out:
# Enter number of elements : 7
# 848549
# 84858
# 483490568
# 2095201
# 19301
# 191
# 17
# [848549, 84858, 483490568, 2095201, 19301, 191, 17]
# The number 2095201 is a prime number
# The number 19301 is a prime number
# The number 191 is a prime number
# The number 17 is a prime number
